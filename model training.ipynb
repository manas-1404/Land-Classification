# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'madrid-es:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F5146647%2F8601919%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240604%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240604T093627Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading madrid-es, 1185389329 bytes compressed
# [==================================================] 1185389329 bytes downloaded
# Downloaded and uncompressed: madrid-es
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Streaming output truncated to the last 5000 lines.
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.53284_-3.66413.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.81459_-3.68693.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.88683_-3.84354.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.88680_-3.73037.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.44219_-3.26948.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.53782_-3.93497.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.46557_-4.06909.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.35587_-3.57556.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.35195_-3.83760.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.92458_-3.54212.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.66685_-3.88272.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.71020_-3.99726.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.09481_-3.60296.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.11075_-3.60957.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.82576_-3.66870.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.52922_-3.54516.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.43947_-3.28016.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.01693_-3.57877.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.16901_-3.35709.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.35042_-3.53060.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.64806_-3.51534.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.23078_-3.09620.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.05313_-3.73562.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.73537_-4.07223.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.42861_-3.57036.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.43164_-3.73713.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.37471_-3.46049.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.33277_-3.63538.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.88326_-3.45570.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.40249_-4.38657.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.59355_-3.99259.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.43071_-3.46894.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51995_-3.59447.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_39.99192_-3.68995.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.30662_-4.41065.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.37074_-3.60061.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.48748_-3.62793.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.40616_-3.78801.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.46862_-4.09429.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.65033_-3.77235.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.77820_-3.71781.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.52957_-3.84354.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.12584_-3.38585.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.45649_-3.60933.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.70724_-3.52243.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.46332_-3.64026.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.72896_-3.87542.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51206_-3.68273.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.28364_-3.68210.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51029_-3.55210.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.38956_-3.94504.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.48253_-3.38405.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.10154_-3.49437.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.97388_-3.63792.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.49392_-3.64287.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.38320_-3.81797.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.81934_-3.71902.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.55252_-3.67004.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.39560_-4.19934.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.30900_-3.85694.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.32665_-3.74125.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.26311_-4.04115.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.44223_-3.85980.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.38211_-3.48191.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41914_-4.19169.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.50634_-4.23818.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.44453_-3.85068.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.38576_-3.60282.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.24637_-3.42791.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.78170_-3.86824.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.58169_-3.91019.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.35113_-3.45794.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.21624_-3.67428.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.34469_-3.88859.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.90783_-3.91819.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41251_-3.65255.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.55158_-4.18936.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.38211_-3.80208.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.16681_-3.83360.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.43265_-3.78398.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.66636_-4.08832.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.42844_-3.80426.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.77049_-3.69595.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.34804_-3.56831.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.42097_-3.42923.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.17243_-3.66861.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.56489_-3.32629.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.48115_-3.36095.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.29986_-3.82128.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.59987_-3.70259.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.24169_-3.42258.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.32567_-3.60834.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.69819_-3.60205.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.49883_-3.72224.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.30463_-3.39229.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.50582_-3.63614.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.22721_-3.41019.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.07883_-3.65815.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.28041_-3.80561.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.46797_-3.67112.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.38434_-4.36303.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.32249_-3.73475.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.33179_-3.78856.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.30385_-3.24821.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.56496_-3.89022.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.42733_-3.61031.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41811_-3.78599.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.71976_-4.01001.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.59559_-4.05533.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.02536_-3.73578.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.64797_-3.78216.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.44351_-3.37068.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.31566_-3.92544.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.20949_-3.89286.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.75972_-4.08512.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.68432_-3.55943.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.54339_-3.64696.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.47631_-3.93845.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.45113_-3.50391.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.32170_-3.80095.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.19609_-3.85083.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.26718_-3.40938.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.38865_-3.78170.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.64244_-4.01154.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.58644_-3.96037.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.66915_-3.98721.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.39645_-3.59840.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.35585_-4.40770.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.62468_-3.61185.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.37612_-3.59856.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.37749_-3.56246.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.38517_-3.63517.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51015_-3.64599.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51261_-4.16171.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.18952_-3.47556.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.61852_-3.61759.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.45133_-3.80490.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.27050_-3.81454.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.50008_-3.33607.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.98667_-3.57324.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.43293_-3.81055.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.42109_-3.98020.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.48830_-3.73806.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.39909_-3.89260.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.50813_-3.62587.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.33332_-4.42387.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51155_-3.68832.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41187_-3.63741.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.18258_-3.70901.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.17943_-3.66522.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.59142_-3.55008.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51373_-3.21964.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.36657_-3.35753.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.27162_-3.70982.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41609_-3.81002.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.34337_-3.57979.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.32442_-3.51644.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.82389_-3.65584.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.48345_-3.90610.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.67938_-3.64083.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.18827_-3.79468.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.01083_-3.61910.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.32708_-3.75457.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.62052_-4.02769.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.47790_-3.85773.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.67219_-3.48158.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.40472_-3.75614.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.52576_-3.31422.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.24946_-3.86170.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51974_-3.77294.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.45119_-3.75416.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.20915_-3.88290.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.42257_-3.76214.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.30992_-3.85076.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.60499_-4.06112.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.12088_-3.61526.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.18531_-3.41236.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.50524_-3.25229.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.35946_-3.47837.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.81896_-3.96046.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.45213_-3.80291.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.32653_-3.71827.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.40771_-3.59569.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.28626_-3.75771.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.40594_-3.95189.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.28305_-4.46005.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.36581_-4.40166.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.54493_-4.14000.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.43450_-3.56015.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.50231_-3.33807.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.34508_-3.77883.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.61940_-4.00361.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.71653_-3.89565.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.33240_-3.71840.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.43171_-3.83814.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.42461_-3.84444.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.97175_-3.77235.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41562_-3.56048.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.09153_-3.41689.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.35226_-3.26641.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.64790_-4.01845.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.59235_-3.67841.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.14292_-3.42457.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.52149_-3.61259.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.03955_-3.60707.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.66089_-4.10576.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.32877_-3.74414.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.36370_-3.72845.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.67989_-3.96449.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.77935_-3.66420.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.46746_-3.81959.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.43175_-3.56402.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.45533_-3.44098.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.62990_-4.01865.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.30763_-3.45921.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.43499_-4.01957.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.44069_-3.78575.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.01490_-3.42650.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.35561_-3.74421.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.52807_-3.61408.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.44796_-3.48355.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.89217_-3.85840.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.28245_-3.50867.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.57656_-3.89599.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.61609_-4.05308.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.36775_-3.61465.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.47596_-3.71768.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.74397_-4.00146.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.71980_-3.98703.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41678_-3.87806.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.78705_-3.83691.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.34209_-3.75032.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.49730_-3.43077.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.58253_-3.72541.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41429_-3.83060.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.44476_-3.57622.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.57265_-3.91976.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.74921_-4.06448.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.31821_-3.70892.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41705_-3.37531.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.05665_-3.70965.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.42519_-3.80046.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.24561_-3.94815.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.67004_-3.39054.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.26399_-3.74186.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.58143_-3.50520.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.52681_-3.63611.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.43764_-3.78261.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.53079_-4.30438.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.55690_-4.12112.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.39397_-3.79617.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.53568_-3.47791.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.45926_-3.44523.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.52722_-3.65130.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.05780_-3.69592.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.04400_-3.65651.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.29042_-4.01240.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.45425_-3.52465.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.23470_-3.58454.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.44584_-3.77998.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.27542_-3.74095.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.57564_-3.88960.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.39240_-3.84635.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.37164_-4.34682.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51255_-3.37409.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.72874_-4.08124.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.43818_-3.88460.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.49569_-3.93871.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.39884_-4.02381.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41015_-3.55762.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.39628_-4.19984.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.34366_-3.72066.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.81654_-3.93835.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.63187_-3.57907.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41565_-3.80357.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.44017_-3.68541.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.01438_-3.65620.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.34425_-3.67714.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.55925_-4.05254.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.48131_-4.16269.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.39715_-3.67694.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.63187_-3.46579.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.39607_-3.25857.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.85362_-3.82181.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.60340_-3.59984.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.66546_-4.12434.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.49234_-3.41908.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.27755_-4.35637.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.24978_-3.64671.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.57127_-3.56043.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.42234_-4.09585.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_39.96758_-3.66428.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.61214_-3.70973.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.65250_-3.95917.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.48313_-3.70753.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.59353_-4.05021.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41346_-3.74865.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.42893_-3.45999.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.02572_-3.65553.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.61245_-3.53968.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.16378_-3.54856.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.37309_-3.79195.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.46545_-4.13630.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51347_-4.26202.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.21413_-3.86975.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.52786_-3.86746.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.48885_-4.04904.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.52365_-3.61345.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.47786_-3.71470.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.59855_-3.97821.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.96749_-3.67792.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.26863_-4.52420.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.49820_-3.70192.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.23644_-3.59182.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.35821_-4.33153.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.53470_-4.24774.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.38916_-3.34140.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.05177_-3.52562.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.67801_-3.91574.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.26980_-3.47075.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.86182_-3.67566.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.28437_-4.02732.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.60848_-3.69153.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.79240_-3.60132.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.35169_-3.71337.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.19552_-3.91995.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.67995_-3.64791.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.43370_-3.73415.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.45317_-3.67812.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.45177_-3.63117.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.26810_-3.39524.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.67539_-4.10061.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.43046_-3.98142.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.37752_-4.09105.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.98887_-3.62668.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.24031_-3.44936.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.67662_-4.11788.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.94148_-3.89719.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.40915_-3.79831.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.31558_-3.49143.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.40838_-3.49703.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41870_-3.68230.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.28997_-3.96154.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.37026_-3.68529.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.39421_-4.39788.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.38429_-4.36804.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51485_-3.97570.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.48859_-3.60059.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.22619_-3.59107.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.25586_-3.57323.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.95099_-3.50190.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.12390_-3.38600.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.40622_-3.87347.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51825_-3.88199.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.59105_-4.26092.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.43202_-3.85289.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.40563_-3.84475.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.54050_-3.76881.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.60163_-3.94583.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.27748_-3.77008.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.47247_-3.60364.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.61068_-4.11250.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.37983_-3.52842.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.71293_-3.50616.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.55338_-4.04898.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.03412_-3.59156.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.67054_-3.64218.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.40781_-3.56609.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.37175_-3.78232.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.06190_-3.57675.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.42346_-3.84563.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.50793_-3.87589.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.24761_-3.30929.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.58433_-3.59176.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.53072_-3.65016.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.54080_-3.48597.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.61475_-4.00738.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.33490_-3.77356.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.36871_-4.29947.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.19951_-3.83220.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.93774_-3.91261.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.39214_-3.62560.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.44179_-3.91066.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.31274_-3.28329.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.68509_-3.54283.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.61489_-4.11947.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51837_-3.67715.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.49072_-3.20614.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.62936_-3.59811.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.36504_-3.64804.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.25487_-3.90223.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.59126_-3.90176.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41122_-3.82206.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.05993_-3.68149.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.25843_-3.87104.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.37947_-3.44193.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.72406_-3.93249.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.73411_-4.06467.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.13607_-3.42410.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.53152_-3.79140.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.63370_-3.99859.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.32137_-3.96770.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.60231_-3.98938.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.29766_-3.66735.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.50620_-3.66664.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.38254_-3.75735.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.28887_-3.73581.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.46925_-3.79407.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.36020_-4.08815.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.19709_-3.88870.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51788_-3.76766.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51125_-3.67788.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.35880_-3.67676.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.66069_-3.53162.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_39.91029_-3.86282.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.79794_-3.97027.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.20670_-3.79179.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.47867_-3.75232.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.61578_-4.12900.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.47857_-3.69574.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.23077_-3.59102.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.45532_-3.85658.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.31269_-3.86642.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.46504_-3.59440.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.59031_-4.13743.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.22481_-3.77801.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.96907_-3.67945.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.50253_-3.51371.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.23347_-3.69901.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.33931_-3.71208.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.37389_-3.92499.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.37497_-3.75783.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.49907_-3.72026.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41017_-3.72617.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.61155_-3.59039.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.44410_-3.36721.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.98660_-3.75084.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51742_-3.61907.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41867_-3.20629.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.38323_-3.92359.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.96896_-3.45638.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.34180_-3.69964.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.45114_-3.80049.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.92136_-3.58462.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.74093_-3.78882.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.34025_-3.57064.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.46401_-3.47689.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.05269_-3.56111.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.57209_-4.26782.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.55920_-3.96987.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.56324_-3.57646.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.30999_-3.89626.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.16959_-3.66014.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.79391_-3.97294.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.66871_-3.76608.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.79318_-3.85492.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.39190_-3.87389.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41536_-3.61316.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.52695_-3.63329.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.67243_-3.39098.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.39018_-3.87037.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.47531_-3.21096.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.30864_-3.44487.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.52303_-3.53677.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.33253_-3.70458.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.38735_-4.35886.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.05304_-3.60788.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.46049_-3.43664.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.28514_-3.31646.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.99293_-3.60459.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.76942_-3.77341.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.45400_-4.22090.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.22992_-3.09619.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.35676_-3.84744.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.64286_-3.60945.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.82872_-3.83604.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.84378_-3.52453.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.50561_-3.32517.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.27324_-3.74790.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.54599_-3.91574.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.46749_-3.77859.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.54820_-3.91473.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.33254_-3.77979.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.01654_-3.57451.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.97914_-3.69787.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.17080_-3.68677.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.67973_-3.98013.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.36294_-3.56969.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.36383_-3.80257.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.40742_-3.86288.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.38811_-3.56232.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.46938_-3.84970.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.05384_-3.65980.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.64448_-4.12528.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.88148_-3.85224.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.49691_-3.71248.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.10520_-3.38473.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.21480_-3.86026.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.49313_-3.35272.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.02768_-3.61079.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.52023_-3.93273.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.67500_-4.09665.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.58574_-3.55463.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.27124_-3.41261.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.80084_-3.59881.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.49886_-3.60268.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.54204_-3.53681.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.47618_-3.39002.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51249_-3.67414.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.28197_-4.23397.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.22076_-3.63126.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.43576_-3.43330.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.54205_-4.29207.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.54849_-4.00425.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.27887_-3.54278.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.07868_-3.44667.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.60996_-4.16749.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.98499_-3.57406.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.36570_-3.74018.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.39495_-3.70163.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.63887_-4.00188.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.89349_-3.52319.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.66410_-3.96637.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.13821_-3.53152.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.21864_-3.99640.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.52650_-3.64215.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.70326_-3.99713.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.22074_-3.75592.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.88774_-3.56367.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.46639_-3.94061.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.79918_-3.96443.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.03697_-3.59493.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.46402_-3.47880.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.53464_-3.30261.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.19707_-3.66515.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.71950_-3.95199.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.52007_-3.53821.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.47144_-3.41123.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.67203_-3.96345.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.31600_-3.30345.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.48460_-3.52256.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.35552_-3.67862.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.24904_-3.76262.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.34230_-3.85098.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.73889_-3.57934.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.36539_-3.63325.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.71708_-3.80287.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.31933_-3.17288.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.31768_-3.44287.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.42822_-3.90451.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.44106_-3.28215.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.41695_-3.86289.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.00924_-3.50060.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.04674_-3.39660.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.91977_-3.56484.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_41.05278_-3.49859.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.33889_-3.87247.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.67954_-3.52310.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.47201_-3.81181.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.95285_-3.73231.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.68494_-3.65806.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.08320_-3.21990.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.21109_-3.32875.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.29043_-3.91603.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.47711_-3.66665.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.51831_-3.98316.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.29406_-3.55970.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.57271_-4.03693.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.40280_-3.71689.jpg
# /kaggle/input/madrid-es/50km/50km/default_value/madrid-es_z17_40.93458_-3.79881.jpg
# ...
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.41249_-3.70819_grid-i77_grid-j26.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43562_-3.64058_grid-i90_grid-j32.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.46646_-3.95261_grid-i30_grid-j40.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.40478_-3.67179_grid-i84_grid-j24.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43176_-3.69779_grid-i79_grid-j31.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.44333_-3.69779_grid-i79_grid-j34.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43562_-3.65619_grid-i87_grid-j32.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.39321_-3.70819_grid-i77_grid-j21.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43176_-3.64058_grid-i90_grid-j31.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.47417_-3.87460_grid-i45_grid-j42.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.42791_-3.66659_grid-i85_grid-j30.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.41634_-3.70819_grid-i77_grid-j27.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43176_-3.65619_grid-i87_grid-j31.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.42020_-3.67699_grid-i83_grid-j28.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.47417_-3.71339_grid-i76_grid-j42.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.40092_-3.67699_grid-i83_grid-j23.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.40863_-3.70299_grid-i78_grid-j25.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.47803_-3.70819_grid-i77_grid-j43.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43176_-3.68739_grid-i81_grid-j31.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43947_-3.64579_grid-i89_grid-j33.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.44718_-3.67699_grid-i83_grid-j35.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.42791_-3.64058_grid-i90_grid-j30.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.48574_-3.65099_grid-i88_grid-j45.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.42405_-3.68219_grid-i82_grid-j29.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.49345_-3.65619_grid-i87_grid-j47.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.50887_-3.67179_grid-i84_grid-j51.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43562_-3.68219_grid-i82_grid-j32.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.50501_-3.70819_grid-i77_grid-j50.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.45104_-3.70819_grid-i77_grid-j36.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.50501_-3.67179_grid-i84_grid-j50.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43176_-3.70819_grid-i77_grid-j31.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43176_-3.64579_grid-i89_grid-j31.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.50501_-3.67699_grid-i83_grid-j50.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.44718_-3.67179_grid-i84_grid-j35.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.48188_-3.71859_grid-i75_grid-j44.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43176_-3.68219_grid-i82_grid-j31.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43562_-3.71859_grid-i75_grid-j32.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.41634_-3.67699_grid-i83_grid-j27.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.55128_-3.65619_grid-i87_grid-j62.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.42405_-3.69259_grid-i80_grid-j29.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.42405_-3.69779_grid-i79_grid-j29.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.44718_-3.78100_grid-i63_grid-j35.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.49345_-3.87460_grid-i45_grid-j47.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43176_-3.70299_grid-i78_grid-j31.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.54357_-3.63538_grid-i91_grid-j60.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.42791_-3.70819_grid-i77_grid-j30.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.52044_-3.92661_grid-i35_grid-j54.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.42405_-3.71339_grid-i76_grid-j29.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.47032_-3.69779_grid-i79_grid-j41.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.50501_-3.70299_grid-i78_grid-j50.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.40863_-3.73939_grid-i71_grid-j25.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43176_-3.67179_grid-i84_grid-j31.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.64766_-3.97861_grid-i25_grid-j87.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.45104_-3.70299_grid-i78_grid-j36.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.42020_-3.69779_grid-i79_grid-j28.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.41249_-3.71339_grid-i76_grid-j26.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.50116_-3.67699_grid-i83_grid-j49.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.42791_-3.70299_grid-i78_grid-j30.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43176_-3.66659_grid-i85_grid-j31.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.38935_-3.66659_grid-i85_grid-j20.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43562_-3.69779_grid-i79_grid-j32.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.42405_-3.70819_grid-i77_grid-j29.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.55128_-3.64058_grid-i90_grid-j62.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43562_-3.69259_grid-i80_grid-j32.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.40478_-3.69259_grid-i80_grid-j24.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43562_-3.70299_grid-i78_grid-j32.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.64766_-3.97341_grid-i26_grid-j87.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.50887_-3.66659_grid-i85_grid-j51.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.40092_-3.69779_grid-i79_grid-j23.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.44333_-3.67699_grid-i83_grid-j34.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.44718_-3.69259_grid-i80_grid-j35.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43176_-3.71859_grid-i75_grid-j31.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.39707_-3.73419_grid-i72_grid-j22.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.39321_-3.71339_grid-i76_grid-j21.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.39707_-3.71859_grid-i75_grid-j22.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43947_-3.67699_grid-i83_grid-j33.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.39707_-3.69259_grid-i80_grid-j22.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.39321_-3.73939_grid-i71_grid-j21.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.46646_-3.69259_grid-i80_grid-j40.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.42791_-3.68739_grid-i81_grid-j30.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.46261_-3.69779_grid-i79_grid-j39.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43562_-3.64579_grid-i89_grid-j32.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.40863_-3.70819_grid-i77_grid-j25.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.40478_-3.69779_grid-i79_grid-j24.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.39707_-3.66659_grid-i85_grid-j22.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.48959_-3.65099_grid-i88_grid-j46.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.48574_-3.65619_grid-i87_grid-j45.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.42405_-3.66659_grid-i85_grid-j29.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.38935_-3.69259_grid-i80_grid-j20.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43947_-3.71339_grid-i76_grid-j33.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.50887_-3.69259_grid-i80_grid-j51.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.55128_-3.65099_grid-i88_grid-j62.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.47417_-3.65099_grid-i88_grid-j42.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.40863_-3.71859_grid-i75_grid-j25.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.47032_-3.94741_grid-i31_grid-j41.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43947_-3.69259_grid-i80_grid-j33.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.46646_-3.94741_grid-i31_grid-j40.jpg
# /kaggle/input/madrid-es/30km/30km/Continuous Urban Fabric (S.L.  80%)/madrid-es_z17_40.43947_-3.65099_grid-i88_grid-j33.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.41249_-3.84860_grid-i50_grid-j26.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.44718_-3.84860_grid-i50_grid-j35.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.42405_-3.87460_grid-i45_grid-j29.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.47803_-3.94221_grid-i32_grid-j43.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.44718_-3.84340_grid-i51_grid-j35.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.41249_-3.84340_grid-i51_grid-j26.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.44333_-3.84860_grid-i50_grid-j34.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.44718_-3.83820_grid-i52_grid-j35.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.40863_-3.84340_grid-i51_grid-j25.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.40478_-3.84340_grid-i51_grid-j24.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.47417_-3.74459_grid-i70_grid-j42.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.46646_-3.72899_grid-i73_grid-j40.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.40092_-3.84340_grid-i51_grid-j23.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.47417_-3.94221_grid-i32_grid-j42.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.40863_-3.84860_grid-i50_grid-j25.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.46646_-3.73419_grid-i72_grid-j40.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.41249_-3.85380_grid-i49_grid-j26.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.53200_-3.90580_grid-i39_grid-j57.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.65152_-3.78100_grid-i63_grid-j88.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.47032_-3.73419_grid-i72_grid-j41.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.47803_-3.74459_grid-i70_grid-j43.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.43947_-3.83820_grid-i52_grid-j33.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.44333_-3.83820_grid-i52_grid-j34.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.44333_-3.84340_grid-i51_grid-j34.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.44333_-3.85900_grid-i48_grid-j34.jpg
# /kaggle/input/madrid-es/30km/30km/Discontinuous Very Low Density Urban Fabric (S.L.  10%)/madrid-es_z17_40.46261_-3.72899_grid-i73_grid-j39.jpg

# %%
import os
import shutil
from random import shuffle

def split_data(source_dir, train_dir, val_dir, test_dir, train_size=0.7, val_size=0.15):
    """
    Split the data into training, validation, and test sets.
    Each set will have its own directory containing subdirectories for each class.

    Parameters:
    - source_dir: Directory containing the dataset's class folders.
    - train_dir: Directory where the training data subdirectories will be stored.
    - val_dir: Directory where the validation data subdirectories will be stored.
    - test_dir: Directory where the test data subdirectories will be stored.
    - train_size: Proportion of the training set (default 0.7).
    - val_size: Proportion of the validation set (default 0.15).
    """
    classes = [d for d in os.listdir(source_dir) if os.path.isdir(os.path.join(source_dir, d))]
    print("Classes found: ", classes)

    if not os.path.exists(train_dir):
        os.makedirs(train_dir)
    if not os.path.exists(val_dir):
        os.makedirs(val_dir)
    if not os.path.exists(test_dir):
        os.makedirs(test_dir)

    for cls in classes:
        cls_dir = os.path.join(source_dir, cls)
        images = [f for f in os.listdir(cls_dir) if os.path.isfile(os.path.join(cls_dir, f))]

        # Shuffle the images to ensure random distribution
        shuffle(images)

        # Calculate split indices
        train_end = int(len(images) * train_size)
        val_end = train_end + int(len(images) * val_size)

        # Split the images into groups
        train_images = images[:train_end]
        val_images = images[train_end:val_end]
        test_images = images[val_end:]

        # Create class directories in train, val, and test
        train_cls_dir = os.path.join(train_dir, cls)
        val_cls_dir = os.path.join(val_dir, cls)
        test_cls_dir = os.path.join(test_dir, cls)

        os.makedirs(train_cls_dir, exist_ok=True)
        os.makedirs(val_cls_dir, exist_ok=True)
        os.makedirs(test_cls_dir, exist_ok=True)

        # Function to copy images to the designated folders
        def copy_images(images, dest_dir):
            for img in images:
                src_path = os.path.join(cls_dir, img)
                dest_path = os.path.join(dest_dir, img)
                shutil.copy(src_path, dest_path)

        # Copy images to their respective folders
        copy_images(train_images, train_cls_dir)
        copy_images(val_images, val_cls_dir)
        copy_images(test_images, test_cls_dir)

# Usage
source_directory = r'/kaggle/input/madrid-es/50km/50km'  # Path to the dataset directory
train_directory = r'/kaggle/working/data/madrid-es/50km/training'
val_directory = r'/kaggle/working/data/madrid-es/50km/evaluation'
test_directory = r'/kaggle/working/data/madrid-es/50km/testing'

split_data(source_directory, train_directory, val_directory, test_directory)
print("Spliting data completed!")
# Out:
# Classes found:  ['Discontinuous Medium Density Urban Fabric (S.L.  30% - 50%)', 'Airports', 'Railways and associated land', 'Fast transit roads and associated land', 'Water bodies', 'Sports and leisure facilities', 'Discontinuous Dense Urban Fabric (S.L.  50% -  80%)', 'default_value', 'Green urban areas', 'Other roads and associated land', 'Industrial, commercial, public, military and private units', 'Discontinuous Low Density Urban Fabric (S.L.  10% - 30%)', 'Construction sites', 'Agricultural + Semi-natural areas + Wetlands', 'Mineral extraction and dump sites', 'Forests', 'Continuous Urban Fabric (S.L.  80%)', 'Discontinuous Very Low Density Urban Fabric (S.L.  10%)']
# Spliting data completed!

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def setup_data_generators(train_dir, val_dir, batch_size=32, target_size=(224, 224)):
    """
    Set up image data generators for training and validation.

    Parameters:
    - train_dir: str, directory containing training data.
    - val_dir: str, directory containing validation data.
    - batch_size: int, size of the batches of data (default: 32).
    - target_size: tuple, dimensions to which all images found will be resized (default: (224, 224)).
    """

    # Setup the training data generator with augmentation
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True
    )

    # Setup the validation data generator
    test_datagen = ImageDataGenerator(rescale=1./255)

    # Prepare flow from directory for training
    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical'
    )

    # Prepare flow from directory for validation
    validation_generator = test_datagen.flow_from_directory(
        val_dir,
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical'
    )

    print("\nPreprocessing of images complete!")

    return train_generator, validation_generator

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input,
    Activation,
    Dense,
    Flatten,
    Conv2D,
    MaxPooling2D,
    AveragePooling2D,
    BatchNormalization,
    Add
)
from tensorflow.keras.regularizers import l2

def _bn_relu(input):
    """Helper function to apply Batch Normalization followed by ReLU."""
    norm = BatchNormalization()(input)
    return Activation("relu")(norm)

def _conv_bn_relu(filters, kernel_size, strides=(1, 1)):
    """Helper function to apply Convolution followed by Batch Normalization and ReLU."""
    def f(input):
        conv = Conv2D(filters=filters, kernel_size=kernel_size, strides=strides,
                      padding="same", kernel_initializer="he_normal",
                      kernel_regularizer=l2(1.e-4))(input)
        return _bn_relu(conv)
    return f

def _bn_relu_conv(filters, kernel_size, strides=(1, 1)):
    """Helper function to apply Batch Normalization, ReLU, and Convolution."""
    def f(input):
        activation = _bn_relu(input)
        return Conv2D(filters=filters, kernel_size=kernel_size, strides=strides,
                      padding="same", kernel_initializer="he_normal",
                      kernel_regularizer=l2(1.e-4))(activation)
    return f

def _shortcut(input, residual):
    """Apply a shortcut connection between input and residual block and merge with Add."""
    input_shape = tf.keras.backend.int_shape(input)
    residual_shape = tf.keras.backend.int_shape(residual)
    stride_width = int(round(input_shape[1] / residual_shape[1]))
    stride_height = int(round(input_shape[2] / residual_shape[2]))
    equal_channels = input_shape[3] == residual_shape[3]

    shortcut = input
    if stride_width > 1 or stride_height > 1 or not equal_channels:
        shortcut = Conv2D(filters=residual_shape[3], kernel_size=(1, 1),
                          strides=(stride_width, stride_height), padding="valid",
                          kernel_initializer="he_normal", kernel_regularizer=l2(0.0001))(input)
    return Add()([shortcut, residual])

def _residual_block(block_function, filters, repetitions, is_first_layer=False):
    """Build a residual block with repeating bottleneck layers."""
    def f(input):
        for i in range(repetitions):
            init_strides = (1, 1)
            if i == 0 and not is_first_layer:
                init_strides = (2, 2)
            input = block_function(filters, init_strides, is_first_block_of_first_layer=(is_first_layer and i == 0))(input)
        return input
    return f

def basic_block(filters, strides=(1, 1), is_first_block_of_first_layer=False):
    """Basic block for ResNet-18 and ResNet-34."""
    def f(input):
        if is_first_block_of_first_layer:
            conv1 = Conv2D(filters=filters, kernel_size=(3, 3), strides=strides,
                           padding="same", kernel_initializer="he_normal",
                           kernel_regularizer=l2(0.0001))(input)
        else:
            conv1 = _bn_relu_conv(filters, (3, 3), strides)(input)

        residual = _bn_relu_conv(filters, (3, 3))(conv1)
        return _shortcut(input, residual)
    return f

def bottleneck(filters, strides=(1, 1), is_first_block_of_first_layer=False):
    """Bottleneck block for ResNet-50, ResNet-101, and ResNet-152."""
    def f(input):
        if is_first_block_of_first_layer:
            conv_1_1 = Conv2D(filters=filters, kernel_size=(1, 1), strides=strides,
                              padding="same", kernel_initializer="he_normal",
                              kernel_regularizer=l2(0.0001))(input)
        else:
            conv_1_1 = _bn_relu_conv(filters, (1, 1), strides)(input)

        conv_3_3 = _bn_relu_conv(filters, (3, 3))(conv_1_1)
        residual = _bn_relu_conv(filters * 4, (1, 1))(conv_3_3)
        return _shortcut(input, residual)
    return f

def ResNetBuilder(input_shape, num_outputs, block_fn, repetitions):
    """Build ResNet architecture based on the block function and repetitions specified."""
    img_input = Input(shape=input_shape)
    conv1 = _conv_bn_relu(64, (7, 7), strides=(2, 2))(img_input)
    pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding="same")(conv1)

    block = pool1
    filters = 64
    for i, r in enumerate(repetitions):
        block = _residual_block(block_fn, filters, r, is_first_layer=(i == 0))(block)
        filters *= 2

    block = _bn_relu(block)
    pool2 = AveragePooling2D(pool_size=(7, 7), strides=(1, 1))(block)
    flatten1 = Flatten()(pool2)
    dense = Dense(units=num_outputs, activation="softmax", kernel_initializer="he_normal")(flatten1)

    model = Model(inputs=img_input, outputs=dense)
    return model

def build_resnet_18(input_shape, num_outputs):
    """Build ResNet-18 architecture."""
    return ResNetBuilder(input_shape, num_outputs, basic_block, [2, 2, 2, 2])

def build_resnet_34(input_shape, num_outputs):
    """Build ResNet-34 architecture."""
    return ResNetBuilder(input_shape, num_outputs, basic_block, [3, 4, 6, 3])

def build_resnet_50(input_shape, num_outputs):
    """Build ResNet-50 architecture."""
    return ResNetBuilder(input_shape, num_outputs, bottleneck, [3, 4, 6, 3])

def build_resnet_101(input_shape, num_outputs):
    """Build ResNet-101 architecture."""
    return ResNetBuilder(input_shape, num_outputs, bottleneck, [3, 4, 23, 3])

def build_resnet_152(input_shape, num_outputs):
    """Build ResNet-152 architecture."""
    return ResNetBuilder(input_shape, num_outputs, bottleneck, [3, 8, 36, 3])

print("ResNet completed")
# Out:
# ResNet completed

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from tqdm.keras import TqdmCallback

# Assuming the 'setup_data_generators' function and 'build_resnet_50' are correctly defined/imported.

# Paths to training and validation data
train_dir = '/kaggle/working/data/madrid-es/50km/training'
val_dir = '/kaggle/working/data/madrid-es/50km/evaluation'

# Initialize data generators
train_generator, validation_generator = setup_data_generators(train_dir, val_dir)

# Build and compile the model
model = build_resnet_50(input_shape=(224, 224, 3), num_outputs=18)
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Define callbacks
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', save_best_only=True, verbose=0)
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=0)
tqdm_callback = TqdmCallback(verbose=1)  # TQDM callback for more interactive progress bar

# Train the model using the tqdm progress bar through the callback
history = model.fit(train_generator,
                    epochs=50,
                    validation_data=validation_generator,
                    callbacks=[checkpoint, early_stop, tqdm_callback],
                    verbose=0)  # Set verbose=0 to prevent default progress bar from showing

# Save the entire model for later use
model.save('madrid_land_model.h5')

print("Training Complete")
# Out:
# Found 24082 images belonging to 18 classes.
# Found 5152 images belonging to 18 classes.
#
# Preprocessing of images complete!
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-40d04d91a57f> in <cell line: 27>()
#      25
#      26 # Train the model using the tqdm progress bar through the callback
# ---> 27 history = model.fit(train_generator,
#      28                     epochs=50,
#      29                     validation_data=validation_generator,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1811                             logs = tmp_logs
#    1812                             end_step = step + data_handler.step_increment
# -> 1813                             callbacks.on_train_batch_end(end_step, logs)
#    1814                             if self.stop_training:
#    1815                                 break
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in on_train_batch_end(self, batch, logs)
#     473         """
#     474         if self._should_call_train_batch_hooks:
# --> 475             self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#     476
#     477     def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     320             self._call_batch_begin_hook(mode, batch, logs)
#     321         elif hook == "end":
# --> 322             self._call_batch_end_hook(mode, batch, logs)
#     323         else:
#     324             raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     343             self._batch_times.append(batch_time)
#     344
# --> 345         self._call_batch_hook_helper(hook_name, batch, logs)
#     346
#     347         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     388             start_time = time.time()
#     389
# --> 390         logs = self._process_logs(logs, is_batch_hook=True)
#     391         for callback in self.callbacks:
#     392             hook = getattr(callback, hook_name)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _process_logs(self, logs, is_batch_hook)
#     295         if is_batch_hook and self._batch_hooks_support_tf_logs:
#     296             return logs
# --> 297         return tf_utils.sync_to_numpy_or_python_type(logs)
#     298
#     299     def append(self, callback):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     692         return t.item() if np.ndim(t) == 0 else t
#     693
# --> 694     return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     695
#     696
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     629     ValueError: If wrong keyword arguments are provided.
#     630   """
# --> 631   return nest_util.map_structure(
#     632       nest_util.Modality.CORE, func, *structure, **kwargs
#     633   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in map_structure(modality, func, *structure, **kwargs)
#    1064   """
#    1065   if modality == Modality.CORE:
# -> 1066     return _tf_core_map_structure(func, *structure, **kwargs)
#    1067   elif modality == Modality.DATA:
#    1068     return _tf_data_map_structure(func, *structure, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in _tf_core_map_structure(func, *structure, **kwargs)
#    1104   return _tf_core_pack_sequence_as(
#    1105       structure[0],
# -> 1106       [func(*x) for x in entries],
#    1107       expand_composites=expand_composites,
#    1108   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in <listcomp>(.0)
#    1104   return _tf_core_pack_sequence_as(
#    1105       structure[0],
# -> 1106       [func(*x) for x in entries],
#    1107       expand_composites=expand_composites,
#    1108   )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     685         # Don't turn ragged or sparse tensors to NumPy.
#     686         if isinstance(t, tf.Tensor):
# --> 687             t = t.numpy()
#     688         # Strings, ragged and sparse tensors don't have .item(). Return them
#     689         # as-is.
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#     392     """
#     393     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 394     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     395     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     396
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#     358   def _numpy(self):
#     359     try:
# --> 360       return self._numpy_internal()
#     361     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#     362       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
model.save('best_model.h5')

print("Training stopped and model saved.")
# Out:
# Training stopped and model saved.

# %%
from google.colab import drive
drive.mount('/content/drive')

model.save('/content/drive/My Drive/best_model.h5')
print("Model saved to Google Drive.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Model saved to Google Drive.
